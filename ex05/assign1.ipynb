# %%
import scipy.stats as ss
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1.

# %%
print("a: ", "{:.3f}".format(ss.norm.ppf(q=0.95, loc=72, scale=8)))
# Out:
# a:  85.159

# %%
print("b: ", "{:.3f}".format(ss.norm.cdf(x=60,loc=72, scale=8)))
# Out:
# b:  0.067

# %% [markdown]
# ### 2.

# %%
lamb = 1/4
print("a :", "{:.3f}".format(1-ss.expon.cdf(x=5, scale=4)))
# Out:
# a : 0.287

# %%
print("b :", "{:.3f}".format(ss.expon.cdf(x=10, scale=4)))
# Out:
# b : 0.918

# %% [markdown]
# ### 3.

# %%
data = np.random.randn(2000)
plt.hist(data, bins=20)
plt.xlabel("x")
plt.ylabel("Frequency")
plt.show()

# %%
x = np.arange(-4, 4, 0.1)
plt.plot(x, [ss.norm.pdf(x=s, loc=0, scale=1) for s in x])
plt.xlabel("x")
plt.ylabel("Frequency")
plt.show()
