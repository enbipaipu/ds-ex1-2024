# %% [markdown]
# ### Environment check

# %%
import numpy as np
print('numpy:', np.__version__, np.__file__)
import scipy as sp
print('scipy:', sp.__version__, sp.__file__)
import pandas as pd
print('pandas:', pd.__version__, pd.__file__)
import sklearn as sk
print('sklearn:', sk.__version__, sk.__file__)
import statsmodels as sm
print('statsmodels:', sm.__version__, sm.__file__)
import seaborn as sns
print('seaborn:', sns.__version__, sns.__file__)
import matplotlib.pyplot as plt
import matplotlib as mp
print('matplotlib:', mp.__version__, mp.__file__)
# Out:
# numpy: 1.21.5 C:\Users\honda\miniconda3\envs\ds2023\lib\site-packages\numpy\__init__.py
# scipy: 1.7.3 C:\Users\honda\miniconda3\envs\ds2023\lib\site-packages\scipy\__init__.py
# pandas: 1.5.3 C:\Users\honda\miniconda3\envs\ds2023\lib\site-packages\pandas\__init__.py
# sklearn: 1.2.1 C:\Users\honda\miniconda3\envs\ds2023\lib\site-packages\sklearn\__init__.py
# statsmodels: 0.13.5 C:\Users\honda\miniconda3\envs\ds2023\lib\site-packages\statsmodels\__init__.py
# seaborn: 0.12.2 C:\Users\honda\miniconda3\envs\ds2023\lib\site-packages\seaborn\__init__.py
# matplotlib: 3.4.3 C:\Users\honda\miniconda3\envs\ds2023\lib\site-packages\matplotlib\__init__.py

# %% [markdown]
# ### Plot

# %%
x = np.linspace(-5, 5, 100)
y = np.exp(x)
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.show()
